# %% [markdown]
# # Тестовое задание
# на  позицию «Product Analyst »
#
# Исполнитель: Сасимович Игорь (ihar.sasimovich@gmail.com, Telegram: http://t.me/ihar367)

# %% [markdown]
# # **Теоретическая часть**

# %% [markdown]
# ### ***Вопрос № 1***
# 💠Что такое LTV?
# 💠Если у нас есть данные за первый месяц жизни приложения, как бы вы рассчитали LTV?
#
# ---

# %% [markdown]
# 💠 <span style="color: #FF4500;">LTV (Lifetime Value),  он же Customer Lifetime Value (CLV)</span> – это показатель ценности клиента, которую он приносит за все время в проекте. Он показывает, сколько денег в среднем принесет один пользователь за все время использования продукта.
#
# Т.е LTV  - это совокупный доход, который приносит один пользователь за все время, пока он остается активным (с момента его привлечения до ухода).
#
# Суть: позволяет оценить общую ценность пользователя для проекта, что помогает определить, сколько можно потратить на его привлечение. В идеале, LTV должен превышать CPA/CPI (Cost Per Acquisition /Install) — стоимость привлечения пользователя, что гарантирует прибыльность маркетинговых усилий.
#  * *Справочно:*  важно учитывать период окупаемости. На начальных этапах проекта, например, в первые месяцы после запуска игры, краткосрочный LTV может быть ниже CPA, но долгосрочный LTV должен перекрывать затраты на привлечение пользователей.
#  * *Справочно:* В SaaS и других моделях бизнеса часто рекомендуется, чтобы LTV был в 3 раза больше CPI для обеспечения привлекательности бизнеса для инвесторов.
#
# Базовая формула рассчёта (одна из формул):
#
# * LTV = ARPU x Lifetime
#
# где
#
# * ARPU (Average Revenue Per User) - средний доход с одного активного пользователя за определенный период времени.
# Суть: метрика, которая позволяет оценить общий доход, получаемый от всех пользователей, включая как платящих, так и неплатящих. Это помогает оценить общую эффективность продукта или услуги.
#
# * Lifetime - среднее время от установки до неактивности.
#
# <br>
#
# 💠Если у нас есть данные только за первый месяц, мы можем оценить LTV через совокупный/накопительный ARPU на N-й день:
#
# * LTV ≈ Cumulative ARPU N day (CARPU N day).
#
# И если мы посчитаем LTV за весь этот месяц, то он будет равен ARPU за 30 дней. Это объясняется тем, что LTV — это накопленный доход с одного пользователя за весь его жизненный цикл, а если мы ограничиваемся первым месяцем, то он равен среднему доходу за эти 30 дней.
#
# ⚠️ Месячный LTV не отражает весь жизненный цикл пользователя.
#
# ⚠️ Важно учитывать когортный анализ:
# ARPU считается как доход, поделенный на аудиторию. А на начальных этапах структура аудитории от дня ко дню очень сильно меняется: допустим, сегодня мы налили трафик и 80 % вашей дневной аудитории – это новички. А через неделю ситуация может измениться и аудитория может состоять уже из относительно опытных (пусть и с недельным стажем) игроков. А ARPU / ARPDAU за оба дня считается по одной и той же формуле и дает совершенно разные значения.
# Поэтому важно считать CARPU в разрезе когорт. Когортный анализ помогает нивелировать эти эффекты и лучше прогнозировать LTV.

# %% [markdown]
# ### ***Вопрос № 2***
#
# 💠Что такое ARPPU?
# 💠В результате изменений в продукте ARPPU снизился. Это хорошо или плохо? Поясните ответ.
#
#    ---

# %% [markdown]
# 💠 <span style="color: #FF4500;"> ARPPU (Average Revenue Per Paying User)</span> — средний доход на одного платящего пользователя за определённый период времени. Этот показатель учитывает только тех, кто сделал хотя бы один платёж.
# Суть: ARPPU важен для оценки эффективности монетизации, так как показывает, насколько хорошо продукт генерирует доход с платящих пользователей. Он помогает понять их реакцию на ценность проекта и изменения в монетизационной стратегии.
#
# Формула для расчёта ARPPU:
#
# * ARPPU = Общий доход от платящих пользователей / Количество платящих пользователей​
#
# <br>
#
# 💠 Снижение ARPPU в результате изменений в продукте может быть как хорошим (точнее сказать неплохим), так и плохим сигналом.
# ARPPU отражает качество монетизации платящих пользователей, но не общий доход (Revenue). А ведь ключевая цель — рост общего дохода и максимизация прибыли, а не только поддержание высокого ARPPU.
# Revenue зависит от двух факторов: количества платящих пользователей и их качества (количества и размера их платежей).
#
# ❌ Плохой сигнал: Снижение ARPPU из-за уменьшения суммы платежей или доли платящих пользователей может указывать на проблемы с монетизацией или ухудшение пользовательского опыта. Если пользователи стали платить меньше или вовсе перестали тратить деньги, значит, изменения в продукте могли негативно повлиять на их поведение.
#
# * Пример: После обновления донатные предметы стали менее полезными ➡️ пользователи покупают их реже ➡️ ARPPU падает, и общий доход тоже.
#
# ✅ Неплохой сигнал: Если ARPPU снижается из-за расширения аудитории (например, за счёт снижения цен, добавления микротранзакций или пересмотра ценовой политики), это может быть позитивным эффектом. В этом случае общее число платящих пользователей растёт, а доход остаётся стабильным или увеличивается, несмотря на снижение ARPPU.
#
# *  Пример: В игру добавили недорогие подписки и скидки на стартовые пакеты ➡️ ARPPU снижается, но общее число платящих пользователей растёт ➡️ общий доход увеличивается.
#
# Снижение ARPPU само по себе не является однозначно плохим или хорошим явлением. Важно анализировать его в связке с Revenue, Paying Share (доля платящих пользователей) и другими метриками. Если при снижении ARPPU общий доход и база платящих пользователей растут, это может быть позитивным результатом. Если же падение ARPPU сопровождается снижением выручки, значит, есть проблемы в монетизации, которые требуют анализа и корректировки.

# %% [markdown]
# ### ***Вопрос № 3***
#
# 💠 При тесте новой маркетинговой компании значительно снизилась стоимость установки, но упал и ретеншн 1 дня. Какие метрики стоит смотреть и какую картину по этим метрикам вы ожидаете увидеть чтобы понять, это хорошо или плохо?
#
# ---

# %% [markdown]
# 💠 <span style="color: #FF4500;"> Retention rate (RR)</span>  - одна из метрик, отражающая «удержание пользователей» игрой. Она говорит о том, продолжают ли люди пользоваться продуктом снова и снова, находят ли они его достаточно ценным (интересным/увлекательным/качественным) для себя. Т.е. данная метрика напрямую связана с пользовательским опытом и качеством продукта. Если пользователю нравится игра или любой другой продукт, он с радостью будет в неё/него возвращаться.
#
# Если коротко, то Retention показывает сколько людей (процент пользователей) вернулись в день Х (неделю Х, месяц Х) после первого входа в продукт (Day 0).
#
# **Бизнес-суть метрики Retention:** Чем дольше пользователь остается в проекте, тем выше вероятность совершения платежа, его размер и/или больше количество просматриваемой рекламы. Соответственно высокий уровень удержания пользователей напрямую влияет на доходность и успешность продукта.
#
# Особое внимание следует уделять 1-Day Retention (RR1). Этот показатель помогают понять, как игроки взаимодействуют с игрой на ранних этапах. Удержание 1-го дня особенно важно, поскольку оно отражает первое впечатление пользователя о проекте и его реакцию на интерфейс и функционал, и в последующем оно влияет на удержание последующих дней.
#
# <br>
#
# Когда снижается стоимость установки (CPI), но падает Retention Rate на 1 день (RR1), это может сигнализировать о проблемах с качеством привлечённого трафика либо же с FTUE (first time user experience).
# Основные причины:
# * Низкокачественный трафик (плохая релевантность аудитории)
# * Изменение структуры трафика, географии и источников
# * Несоответствие креативов реальному продукту
# * Проблемы с онбордингом или первым игровым опытом
# * Проблемы с монетизацией (агрессивная монетизация и/или слишком высокая цена внутриигровых покупок)
# * Технические проблемы
#
# Чтобы точно понять причину, важно смотреть структуру трафика, качество первых сессий и дальнейшее поведение пользователей.
#
# <br>
#
# Если CPI снизился, но RR1 упал, важно понять, привело ли это к общему росту прибыли или ухудшению качества аудитории. Для этого смотрим на следующие метрики:
#
# Монетизация:
#
# 1. Revenue
# ✅ Если доход вырос или остался стабильным – снижение CPI может быть оправдано, даже если RR1 упал.
# ❌ Если доход снизился – возможно, новый трафик не конвертируется в платежи, трафик низкокачественный.
#
# 2. ARPU
# ✅ Если ARPU растёт или остаётся стабильным – можно не беспокоиться о падении RR1.
# ❌ Если ARPU падает – новый трафик приносит меньше денег.
#
# 3. ARPPU
# ✅ Если ARPPU растёт или остаётся стабильным – это хорошо.
# ❌ Если ARPPU снижается – значит, новые пользователи платят меньше или платящих стало меньше.
#
# Качество трафика:
#
# 4.  RR 7 и RR30
# ✅ Если падение RR1 не влияет на RR7 и RR30 – возможно, новый трафик просто требует больше времени на вовлечение.
# ❌ Если RR7 и RR30 тоже падают – значит, пользователи не задерживаются.
#
# 5. Доля платящих пользователей (Paying Share, Conversion to Paying User)
# ❌ Если доля платящих пользователей падает, значит, новый трафик менее конверсионный.
# ✅ Если Paying Share стабильна – значит, просто появилось больше бесплатных пользователей, но платящие ведут себя как раньше.
#
# 6. LTV
# ❌ Если LTV новых пользователей ниже, чем у старых – значит, трафик дешёвый, но бесполезный.
#
# 7. CR
# CR по каналам покажет, какие источники дают наименее вовлечённых пользователей – если один из каналов резко выделяется, его стоит проверить в первую очередь.
#
# Поведение пользователей:
#
# 8. D1 Event Funnel (Воронка событий первого дня). Анализируем, на каком шаге пользователи уходят.
# ❌ Если больше людей выходит после загрузки – проблема в рекламных креативах.
# ❌ Если выходят после туториала – проблема в онбординге.
# ✅ Новые пользователи должны доходить до ключевых событий.
#
# 9.  Bounce Rate (Процент мгновенных выходов)
# ❌ Если пользователи выходят сразу после первого запуска – вероятно, проблема в трафике.
#
#
# ### Вывод
#
# Если CPI снизился, но RR1 упал, а....
#
# | Критерий                     | ✅ Хорошо / Неплохо  | ❌ Плохо    |
# |------------------------------|----------------------|--------------|
# | Общий доход                  | Растёт или стабилен  | Падает       |
# | ARPU, ARPPU, LTV             | Не падают            | Снижаются    |
# | RR7 и RR30                   | Не снижаются         | Тоже падают  |
# | Доля платящих пользователей  | Не падает            | Падает       |
#
# Если ситуация "плохая", необходимо более детально анализировать:
#
# 🔹 Источники трафика – в разрезе каналов, стран, платформ, версий игры (есть ли аномалии, изменения в структуре трафика).
# 🔹 Креативы – соответствуют ли они реальному игровому процессу, не вводят ли пользователей в заблуждение.
# 🔹 Первые сессии и онбординг – на каких этапах пользователи теряются (D1 Event Funnel, Bounce Rate, туториал).
# 🔹 Монетизацию – не отпугивает ли пользователей слишком агрессивная реклама или завышенные цены на внутриигровые покупки.
# 🔹 Технические аспекты – наличие багов, проблемы с производительностью, долгие загрузки.
#
# Только комплексный анализ поможет определить, является ли снижение RR1 критичной проблемой или это естественная реакция на изменения в трафике.
#
# <br>
#
# --- --- --- --- ---
#
# <br>

# %% [markdown]
# # **Практическая часть**

# %% [markdown]
# ### ***Задание № 1***
# Установите игру “Atlantis Odyssey” из Google Play или AppStore (в зависимости от устройства в наличии). Поиграйте столько, сколько вам необходимо для получения общего понимания игры.

# %% [markdown]
# ![It's done](https://github.com/i-sasimovich/data_analytics_portfolio/blob/main/01_game_analytics_projects/ga_prj_07_adventure_game_engagement_monetization/screenshot_2025-03-14_07-33-00.jpg?raw=true)
#
#
# <span style="color: #FF4500;"> **Atlantis Odyssey** </span> — это мобильная игра, которая сочетает в себе элементы симулятора, фермерства, приключений и управления ресурсами.
# Краткий разбор её ключевых аспектов:
#
# Основные механики:
# * Исследование: Игроки очищают территорию от препятствий (растений, камней), чтобы открыть новые области и продвигаться по сюжету. Это требует энергии, которая восстанавливается со временем.
# * Фермерство и производство: Выращивание культур, разведение животных и создание ресурсов для выполнения заданий.
# * Квесты: Выполнение сюжетных и побочных заданий, которые помогают продвигаться в игре и получать награды.
# * Управление лагерем: Постройка и улучшение зданий, таких как фабрики и склады, для оптимизации производства и хранения ресурсов.
#
# Игровые циклы:
# * Сбор ресурсов: Игроки добывают материалы, такие как дерево, камень и еда, для выполнения задач.
# * Производство: Использование ресурсов для создания предметов, необходимых для выполнения квестов.
# * Исследование: Расход энергии на открытие новых территорий и выполнение сюжетных миссий.
# * Прогресс: Завершение заданий, улучшение лагеря и продвижение по сюжету.
#
# Модель монетизации :
# * Энергия: Основной ограничивающий ресурс, без которого прогресс ро игре не возможен. Игроки могут ждать её восстановления или покупать за реальные деньги.
# * Внутриигровая валюта: Покупка ресурсов и энергии, ускорение процессов и доступ к эксклюзивным предметам.
# * Премиум-предложения: Специальные наборы, такие как "Золотой пропуск" или "Копилка самоцветов", которые дают бонусы за определённую плату.
# * Реклама: Возможность получить небольшие бонусы, просмотрев рекламные ролики.
#
# Итак, Atlantis Odyssey - это FREE-TO-PLAY игра, которая сочетает в себе следующие способы монетизации:
# ● In-App Purchases – единоразовая покупка за реальные деньги.
# ● Ad monetization – просмотр рекламы для получения бонуса.
#
# Игра ориентирована на неспешный прогресс, но предлагает ускорение за счёт микротранзакций. Это делает её привлекательной как для казуальных игроков, так и для тех, кто готов вкладывать средства для быстрого продвижения.

# %% [markdown]
# ### ***Задание № 2***
# Дана SQL-база, содержащая данные за первые 10 дней жизни в игре по когорте пользователей. Посмотрите и проанализируйте вовлечение и монетизацию когорты:
#
# 💠 Вовлечение:
# - Рассчитайте ретеншн и время, которое игроки проводят в игре.
# - Предложите и рассчитайте метрики необходимые на ваш взгляд для анализа воронки вовлечения
#
# 💠 Монетизация:
# - Рассчитайте общие показатели монетизации для когорты
# - Предложите и рассчитайте метрики необходимые на ваш взгляд для анализа воронки монетизации
#
# 💠 Проблемные точки:
# - Какие наиболее проблемные квесты/уровни вы бы выделили и предложили к доработкам? Почему?
# - Как выглядели бы целевые метрики в аб-тесте правок этих проблемных точек?
#
# Какие участки игры вы бы предложили изменить и протестировать по итогу анализа? Почему?
#
# <br>
#
# | Таблица        | Описание             | Поля                                                                 |
# |----------------|----------------------|----------------------------------------------------------------------|
# | quest_complete | Выполнение квеста     | `user_id` (string), `time` (timestamp), `quest` (string)             |
# | quest_start    | Получение квеста      | `user_id` (string), `time` (timestamp), `quest` (string)             |
# | payment        | Совершение платежа    | `user_id` (string), `time` (timestamp), `amount` (numeric)           |
# | level_up       | Получение уровня      | `user_id` (string), `time` (timestamp), `level` (numeric)            |
# | session        | Окончание сессии      | `user_id` (string), `close_time` (timestamp), `open_time` (timestamp), `duration` (numeric, seconds) |
# | install        | Установка игры        | `user_id` (string), `reg_time` (timestamp)                           |
#
# -----

# %% [markdown]
# Для выполнения задания я буду использовать СУБД <span style="color:#FF7F50"> **PostgreSQL (v 16.4)**</span>  и python-библиотеку <span style="color:#FF7F50"> **SQLAlchemy**</span>.

# %%
# 1. Импортируем необходимые библиотеки.
import pandas as pd
import numpy as np

from sqlalchemy import create_engine, text

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 2. Создадим подключение и функцию для выполнения SELECT-запросов.
conn = create_engine('postgresql+psycopg2://postgres:maz505+5@localhost:5432/atlantis_odyssey')

def select(sql):
    with conn.connect() as connection:
        return pd.read_sql(sql, connection)

# %%
# проверим
select('''SELECT table_name FROM information_schema.tables WHERE table_schema = 'public';''')
# Out:
#        table_name
# 0         install
# 1        sessions
# 2        level_up
# 3         payment
# 4     quest_start
# 5  quest_complete

# %% [markdown]
# ### 💠 Вовлечение

# %%
### Retention
# 1. Точкой отсчёта (каркасом когорт) будет дата установки, на основании которой формируются когорты. 
# 2. Рассчитаем размер каждой когорты. 
# 3. Составим уникальный список дней, когда пользователи были активны (все дни активности пользователей). CTE activity создаёт базу для расчёта retention.
# 4. Создадим таблицу retention_data. rday показывает разницу между датой сессии и датой первой сессии. т.е. rday — это количество дней, прошедших с первой сессии (D+0), добавим сюда и размер когорты.
# 5. Расчитаем Retention. 


sql = '''
WITH 
cohort_size AS (
    SELECT DATE(reg_time) AS cohort_date, COUNT(DISTINCT user_id) AS cohort_size
    FROM install
    GROUP BY cohort_date
),

activity AS (
    SELECT DISTINCT user_id, DATE(open_time) AS activity_date
    FROM sessions
),

retention_data AS (
    SELECT DATE(i.reg_time) AS cohort_date,
           cs.cohort_size,
           CAST((a.activity_date - DATE(i.reg_time)) AS INT) AS rday,
           i.user_id
    FROM install i
    JOIN cohort_size cs ON DATE(i.reg_time) = cs.cohort_date 
    LEFT JOIN activity a ON i.user_id = a.user_id 
)


SELECT cohort_date, 
       MAX(cohort_size) AS cohort_size, 
       rday, 
       ROUND(COUNT(DISTINCT user_id) * 100.0 / MAX(cohort_size), 2) AS rr 
FROM retention_data
WHERE rday BETWEEN 1 AND 10 
GROUP BY cohort_date, rday
ORDER BY cohort_date, rday;


'''
df = select(sql)

# 6. Адаптируем наш df для тепловой карты.
# Хочу, чтобы на графике отражался ещё и размер когорты, для этого создадим новую колонку "cohort_label" на основе колонок "cohort_date" и "cohort_size". Затем, создадим сводную таблицу.
# 7. Визуализируем результат.

df["cohort_label"] = df["cohort_date"].astype(str) + "\nN=" + df["cohort_size"].astype(str)
df_pivot = df.pivot(index=["cohort_label"], columns="rday", values="rr")


plt.figure(figsize=(10, 6))
sns.heatmap(df_pivot, cmap="YlGnBu", annot=True, fmt=".2f", linewidths=0.5)
plt.xlabel("Retention Period")
plt.ylabel("Cohort Date")  
plt.title("Retention Heatmap")

plt.show()

# %% [markdown]
# В данном анализе рассчитан Classic Retention для 10 когорт (период с 2020-10-05 по 2020-10-14) на протяжении 10 дней. Размеры когорт существенно различаются: самая маленькая — 2020-10-05 (380 игроков), самая большая — 2020-10-10 (8130 игроков).
#
# С 8 по 12 октября наблюдается резкий приток пользователей, вероятно, связанный с маркетинговой активностью. До 8 октября размеры когорт были относительно небольшими (от 380 до 591 пользователей), однако начиная с 8 октября их количество значительно увеличилось:
# - 8 октября — 1210 игроков
# - 9 октября — 4855
# - 10 октября — 8130 (максимум)
# - 11 октября — 7129
# - 12 октября — 4991
#
# После 12 октября размер когорт начинает снижаться: 13 октября — 1634, 14 октября — 1772, что может быть связано с завершением маркетинговой кампании, исчерпанием рекламного бюджета или снижением трафика.
#
# Удержание пользователей в первый день после установки (RR1) варьируется от 41.32% до 62.48% в зависимости от когорты. Особенно высокие показатели у когорт 13 и 14 октября (более 60%), а также у 7 и 11 октября (более 58%), что может свидетельствовать об удачных источниках трафика, эффективном онбординге или высоком качестве привлечённой аудитории.
#
# Когорты  8 и 10 октября демонстрируют заметно более низкое удержание RR1:
# - 8 октября — 41.32%
# - 10 октября — 46.59%
#
# При этом RR7 (удержание на седьмой день) у этих когорт составляет:
# - 8 октября — 15.04%
# - 9 октября — 17.20%
# - 10 октября — 15.24%
#
# Это ниже референтных значений, особенно на фоне когорт 11–14 октября, где RR7 держится на уровне 22–26%. Падение RR7 может указывать на проблемы с долгосрочной вовлечённостью, нецелевую аудиторию или слабые контентные механики.
#
# Хотя на первый взгляд может показаться, что увеличение размера когорт приводит к снижению удержания, когорты 11, 12 и 13 октября не подтвержают эту гипотезу. Несмотря на крупный объём, они показывают высокие значения RR1 и RR7. Это подчёркивает важность качества трафика, а не его количества.
#
# Игроки в целом демонстрируют устойчивое удержание на D+1 и D+2, но далее — ожидаемое снижение. Однако когорты 11–14 октября показывают более «пологий» спад, что может быть следствием более качественного онбординга и контента.
#
# В дальнейшем рекомендуется:
# - провести сегментацию по каналам привлечения;
# - проанализировать первые игровые сессии (онбординг);
# - изучить поведение игроков после D+5, чтобы выявить причины резкого оттока на D+7 и D+10;
# - протестировать гипотезы по улучшению удержания через контент, внутриигровые события или механики прогрессии.
#
# *Справочно: согласно книге Василия Сабирова «Игра в цифры. Как аналитика позволяет видеоиграм жить лучше», средне-хорошие значения удержания составляют: 40% на 1-й день, 20% на 7-й день и 10% на 28-й день. Эти показатели могут варьироваться в зависимости от типа продукта.*

# %%
### Время, которое игроки проводят в игре.
# Выгрузим данные

sql = '''
WITH    
cohort_size AS (
    SELECT DATE(reg_time) AS cohort_date, COUNT(DISTINCT user_id) AS cohort_size
    FROM install
    GROUP BY cohort_date
)


SELECT
    DATE(i.reg_time) AS cohort_date, 
    cs.cohort_size, 
    s.user_id, 
    s.close_time, 
    s.open_time, 
    s.duration  
FROM install i
JOIN sessions s USING (user_id)
JOIN cohort_size cs ON DATE(i.reg_time) = cs.cohort_date;
'''

df = select(sql)
df.head(2)
# Out:
#   cohort_date  cohort_size    user_id              close_time  \
# 0  2020-10-10         8130  862965630 2020-10-10 10:17:59.063
# 1  2020-10-10         8130    5569239 2020-10-10 11:48:24.723
#
#                 open_time  duration
# 0 2020-10-10 10:06:09.873   709.190
# 1 2020-10-10 11:47:34.042    50.681

# %%
# df.dtypes

# Приводим типы данных
df["user_id"] = df.user_id.astype(int)
# Из секунд в минуты
df["duration"] = df.duration / 60

df["cohort_label"] = df["cohort_date"].astype(str) + " (N=" + df["cohort_size"].astype(str) + ")"
df.head(2)
# Out:
#   cohort_date  cohort_size    user_id              close_time  \
# 0  2020-10-10         8130  862965630 2020-10-10 10:17:59.063
# 1  2020-10-10         8130    5569239 2020-10-10 11:48:24.723
#
#                 open_time   duration         cohort_label
# 0 2020-10-10 10:06:09.873  11.819833  2020-10-10 (N=8130)
# 1 2020-10-10 11:47:34.042   0.844683  2020-10-10 (N=8130)

# %%
# Рассчитываем статистики по длительности сессий
session_stats = df.groupby("cohort_label")["duration"].agg(
    min_session_duration="min",
    avg_session_duration="mean",
    q25_session_duration=lambda x: x.quantile(0.25),
    median_session_duration="median",
    q75_session_duration=lambda x: x.quantile(0.75),
    q95_session_duration=lambda x: x.quantile(0.95),
    max_session_duration="max"   
).reset_index()

# Рассчитываем среднее количество сессий на пользователя
avg_sessions_per_user = df.groupby("cohort_label").agg(
    total_sessions=("user_id", "count"),
    unique_users=("user_id", "nunique")
)
avg_sessions_per_user["avg_sessions_per_user"] = (
    avg_sessions_per_user["total_sessions"] / avg_sessions_per_user["unique_users"]
)

# Объединяем результаты
session_stats = session_stats.merge(
    avg_sessions_per_user[["avg_sessions_per_user"]], 
    on="cohort_label"
)

session_stats
# Out:
#           cohort_label  min_session_duration  avg_session_duration  \
# 0   2020-10-05 (N=380)                   0.0             12.868846
# 1   2020-10-06 (N=423)                   0.0             11.500615
# 2   2020-10-07 (N=591)                   0.0             11.504816
# 3  2020-10-08 (N=1210)                   0.0             12.896855
# 4  2020-10-09 (N=4855)                   0.0             12.260344
# 5  2020-10-10 (N=8130)                   0.0             12.340622
# 6  2020-10-11 (N=7129)                   0.0             12.476596
# 7  2020-10-12 (N=4991)                   0.0             12.911551
# 8  2020-10-13 (N=1634)                   0.0             13.610879
# 9  2020-10-14 (N=1772)                   0.0             11.630369
#
#    q25_session_duration  median_session_duration  q75_session_duration  \
# 0              2.527596                 6.845742             15.447121
# 1              2.165117                 6.152433             14.261750
# ...

# %%
# Посчитаем количество сессий с длительностью равной нулю.
df[df.duration == 0].user_id.count()
# Out:
# 2631

# %% [markdown]
# На первый взгляд, поведение всех когорт похоже — медиана и квартильные значения остаются в пределах разумных отклонений. Однако аномально длинные сессии (до 1365 минут) могут быть связаны либо с техническими особенностями (например, игра остается запущенной в фоновом режиме), либо с ботами.
#
# Аномально короткие сессии (немного >= 0 минут) тоже могут указывать на проблемы — возможно, это пользователи, которые сразу же выходят из игры, не проявляя интереса. Если таких случаев много, стоит дополнительно изучить причины: возможно, техничкие проблемы или неподходящей рекламной кампании, привлекающей нерелевантную аудиторию.
#
# Среднее количество сессий на пользователя варьируется, что может указывать на разную степень вовлеченности когорт. Например, 12 октября 2020 года пользователи запускали игру чаще, чем в другие дни, тогда как 8 и 10 октября этот показатель был минимальным. Это может быть связано с внутриигровыми событиями или качеством привлеченной аудитории.
#
# В целом, без детального анализа сложно делать окончательные выводы, но в текущих данных явных аномалий среди основных статистик нет, кроме уже отмеченных крайних значений.
#
# ⚠️Необходим более детальный анализ.

# %%
# Построим распределение длительности сессий

plt.figure(figsize=(8, 6))
sns.histplot(df.duration, kde=True)
plt.xlabel('Длительность сессии, мин.');
plt.ylabel('Количество сессий');
plt.title('Распределение значений длительности сессий');
sns.despine()

# %% [markdown]
# Как мы видим, распределение правосторонне скошенное. Все значения данного распределения >= 0.
# Исходя из предоставленных описательных статистик и гистограммы, мы видим, что данные имеют скошенное распределение с длинным правым хвостом. Это указывает на то, что большинство сессий имеют небольшую длительность, но есть некоторое количество сессий с очень длительными значениями, что приводит к скошенности данных.
#
# Медиана значительно меньше среднего значения, что указывает на наличие выбросов в данных, которые существенно влияют на среднее значение. Есть экстремальные значения, которые могут искажать средние показатели. Также они могут быть связаны с аномалиями или ботами. По-хорошему, нужен более глубокий анализ аномальных сессий.
#
# Продолжительность сессий во многом зависит от типа продукта. Для казуальных игр короткие, но частые сессии могут быть нормой. Если говорить про такой проект, как “Atlantis Odyssey”, то я думаю, что меньше 5 минут сессии нельзя считать полноценными 😅
#
# <br>
#
# Разобьём сессии на группы по их длительности и визуализируем распределения.
#
# *Справочно: Разбиение на группы должно существляться c учётом бизнес-логики и контекста, важно исходить из целей анализа, а также иметь представление о поведении пользователей в игре.*
#
# Исходя из своего игрового опыта в “Atlantis Odyssey” и понимания логики игры предлагаю следущий вариант разбивки:

# %%
duration_group_labels = ['Подозрительно короткая [0, 1)', 
                         'Короткая [1, 5)', 
                         'Нормальная  [5, 20)', 
                         'Длинная [20, 60)', 
                         'Очень длинная [60, 90)', 
                         'Подозрительно длинная [90+)']


dur_bins = [0, 1, 5, 20, 60, 90, df['duration'].max() + 1]


df['duration_groups'] = pd.cut(df['duration'],
                               bins=dur_bins,
                               labels=duration_group_labels,
                               right=False)

df.head(2)
# Out:
#   cohort_date  cohort_size    user_id              close_time  \
# 0  2020-10-10         8130  862965630 2020-10-10 10:17:59.063
# 1  2020-10-10         8130    5569239 2020-10-10 11:48:24.723
#
#                 open_time   duration         cohort_label  \
# 0 2020-10-10 10:06:09.873  11.819833  2020-10-10 (N=8130)
# 1 2020-10-10 11:47:34.042   0.844683  2020-10-10 (N=8130)
#
#                  duration_groups
# 0            Нормальная  [5, 20)
# 1  Подозрительно короткая [0, 1)

# %%
# Посмотрим на распределение данных по группам
dg_value_counts = df.duration_groups.value_counts()
dg_value_counts_norm = round(df.duration_groups.value_counts(normalize=True) * 100, 2)

print("Размер каждой группы:")
print(dg_value_counts)
print('--- --- ---')
print("Относительные частоты каждой группы '%':")
print(dg_value_counts_norm)

total_count = len(df)
print('--- --- ---')
print(f"Общее количество записей: {total_count}")
# Out:
# Размер каждой группы:
# duration_groups
# Нормальная  [5, 20)              151351
# Короткая [1, 5)                  109768
# Длинная [20, 60)                  56635
# Подозрительно короткая [0, 1)     32372
# Очень длинная [60, 90)             5138
# Подозрительно длинная [90+)        2770
# Name: count, dtype: int64
# --- --- ---
# Относительные частоты каждой группы '%':
# duration_groups
# Нормальная  [5, 20)              42.27
# Короткая [1, 5)                  30.66
# Длинная [20, 60)                 15.82
# Подозрительно короткая [0, 1)     9.04
# Очень длинная [60, 90)            1.44
# Подозрительно длинная [90+)       0.77
# Name: proportion, dtype: float64
# --- --- ---
# Общее количество записей: 358034

# %%
# Сначала посмотрим на распределение по группам. Визуализируем
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=dg_value_counts.index, y=dg_value_counts.values, hue=dg_value_counts.index, palette="viridis")

# Добавляем подписи
for p in ax.patches:
    ax.annotate(f'{p.get_height():.0f}',  # Значение на столбце
                (p.get_x() + p.get_width() / 2., p.get_height()),  # Позиция подписи
                ha='center', va='center',  # Горизонтальная и вертикальная выравнивание
                fontsize=10, color='black',  # Размер и цвет шрифта
                xytext=(0, 5),  # Сдвиг подписи вверх
                textcoords='offset points')

plt.title('Распределение продолжительности сессий по категориям', fontsize=16)
plt.xlabel('Категория продолжительности сессий', fontsize=12)
plt.ylabel('Количество', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# А теперь ещё и в разрезе когорт

# Группировка по дате и категории продолжительности с подсчетом количества
dg_value_counts = df.groupby(['cohort_date', 'duration_groups'], observed=False).size().reset_index(name='count')

# Строим барплот
plt.figure(figsize=(12, 6))
sns.barplot(x='cohort_date', y='count', hue='duration_groups', data=dg_value_counts, palette="viridis")

# Настроим внешний вид
plt.title('Распределение продолжительности сессий по категориям', fontsize=16)
plt.xlabel('Дата когорты', fontsize=12)
plt.ylabel('Количество', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# На основе имеющихся данных можно сделать следующие выводы:
#
# 1. Топ-3 категории. В сумме эти три категории составляют около 88.75% всех сессий:
# - Наибольшее количество сессий (42.27%) попадает в категорию «Нормальная [5, 20)».
# - Категория «Короткая [1, 5)» занимает 30.66%, что говорит о том, что значительная часть пользователей завершает сессию за короткое время.
# - Категория «Длинная [20, 60)» занимает 15.82%.
#
# 2. Категория «Подозрительно короткая [0, 1)» составляет 9.04%.
#
# 3. Категории «Очень длинная [60, 90)» (1.44%) и «Подозрительно длинная [90+)» (0.77%) имеют минимальную долю, что указывает на редкость сессий очень долгой продолжительности.
#
# 4. Подобная структура сессий сохраняется во всех когортах. Не выявлено аномальных отклонений.
#
# Основная масса пользователей проводит сессии продолжительностью от 1 до 60 минут, причем наиболее распространена категория средней продолжительности «Нормальная [5, 20)». Также значительная часть пользователей завершает сессии в пределах 1–5 минут. Сессии, которые значительно длиннее или короче, встречаются гораздо реже. Это распределение важно учитывать для оптимизации пользовательского опыта и разработки функционала, ориентированного на наиболее частые паттерны использования.
#
# ✴️ Рекомендация: Следует обратить внимание на подозрительно короткие и длинные сессии, так как они могут указывать на специфическое поведение пользователей или технические проблемы.
#
# ⚠️ Необходим более детальный анализ, понимание контекста и больше данных для более точных выводов.

# %% [markdown]
# #### *Метрики необходимые на мой взгляд для анализа воронки вовлечения* :
# Конверсии по этапам вовлечения:
#
# Установки → Доля игроков с первой сессией → Доля игроков со второй сессией → Доля игроков, достигших уровня N (например 10 уровня) → Доля игроков, совершивших первый платеж

# %%
# 1. Определяем пользователей, у которых была первая сессия после установки  
# 2. Определяем пользователей, которые совершили вторую сессию  
# 3. Определяем пользователей, достигших уровня N (например, 10)  
# 4. Определяем пользователей, совершивших первый платеж  
# 5. Рассчитываем конверсии от установок по когортам  


sql = '''

WITH 
first_session AS (
    SELECT DISTINCT s.user_id
    FROM sessions s
    JOIN install i ON s.user_id = i.user_id 
    WHERE s.open_time >= i.reg_time
),

second_session AS (
    SELECT s.user_id
    FROM sessions s
    JOIN first_session f ON s.user_id = f.user_id
    GROUP BY s.user_id
    HAVING COUNT(*) >= 2
),

level_N AS (
    SELECT DISTINCT user_id 
    FROM level_up
    WHERE level >= 10
),

first_payment AS (
    SELECT DISTINCT user_id
    FROM payment
)


SELECT 
    DATE(i.reg_time) AS cohort_date,
    COUNT(DISTINCT i.user_id) AS total_installs,
    ROUND( (COUNT(f.user_id) * 1.0) / NULLIF(COUNT(i.user_id), 0), 3) AS install_to_first_session_conversion,
    ROUND( (COUNT(s.user_id) * 1.0) / NULLIF(COUNT(i.user_id), 0), 3) AS install_to_second_session_conversion,
    ROUND( (COUNT(l.user_id) * 1.0) / NULLIF(COUNT(i.user_id), 0), 3) AS install_to_levelN_conversion,
    ROUND( (COUNT(p.user_id) * 1.0) / NULLIF(COUNT(i.user_id), 0), 3) AS install_to_payment_conversion
FROM install i
LEFT JOIN first_session f ON i.user_id = f.user_id
LEFT JOIN second_session s ON i.user_id = s.user_id
LEFT JOIN level_N l ON i.user_id = l.user_id
LEFT JOIN first_payment p ON i.user_id = p.user_id
GROUP BY 1
HAVING COUNT(DISTINCT i.user_id) > 10
ORDER BY 1;

'''

select(sql)
# Out:
#   cohort_date  total_installs  install_to_first_session_conversion  \
# 0  2020-10-05             380                                0.997
# 1  2020-10-06             423                                1.000
# 2  2020-10-07             591                                1.000
# 3  2020-10-08            1210                                0.998
# 4  2020-10-09            4855                                0.998
# 5  2020-10-10            8130                                1.000
# 6  2020-10-11            7129                                0.998
# 7  2020-10-12            4991                                0.998
# 8  2020-10-13            1634                                0.997
# 9  2020-10-14            1772                                0.999
#
#    install_to_second_session_conversion  install_to_leveln_conversion  \
# 0                                 0.634                         0.163
# 1                                 0.596                         0.142
# ...

# %% [markdown]
# Анализ конверсий по когортам с 2020-10-05 по 2020-10-14 показывает интересные особенности поведения пользователей.
#
# 🔹 Конверсия в первую сессию (install_to_first_session_conversion) близка к 1.0 (от 0.997 до 1.0) у всех когорт, что говорит о том, что практически каждый установивший игру хотя бы один раз её запускал. Это нетипично для реальных данных и может быть связано с особенностями трекинга, автоматическими запусками приложения или ошибками логирования. При этом факт, что у некоторых установок отсутствует open_time первой сессии или сессия не закрыта (session_close), требует дополнительного изучения.
#
# 🔹 Конверсия во вторую сессию заметно проседает у когорт 8–10 октября — от 0.490 до 0.511, в то время как в другие даты она выше (до 0.708). Это может свидетельствовать о проблемах с онбордингом, нецелевом трафике или технических трудностях у новых пользователей. После 10 октября метрика восстанавливается, особенно у когорт 11–13 октября.
#
# 🔹 Конверсия в достижение 10+ уровня (install_to_leveln_conversion) колеблется от 0.076 до 0.166. Наименьшие значения фиксируются также у когорт с 8 по 10 октября, что подтверждает гипотезу о низком качестве привлечённой в эти дни аудитории или недостаточном интересе к контенту на ранних этапах игры.
#
# 🔹 Конверсия в платеж (install_to_payment_conversion) в целом остаётся низкой и нестабильной (0.002–0.014), но обращают на себя внимание резкие всплески 13 октября (5.6%) и 14 октября (4.0%). Эти пики могут быть следствием запуска акций, появления привлекательных предложений в магазине или ошибок в трекинге, и требуют отдельного расследования.
#
# ⚠️ Важно: Анализ учитывает сессии с экстремальными значениями длительности или активности, которые могут искажать метрики. В рамках текущего дедлайна не удалось провести полноценную очистку данных, однако на этапе финального анализа это обязательно следует учесть. Такие выбросы могут существенно повлиять на интерпретацию поведения пользователей.
#
# ⚠️ Также для более точных выводов необходим более глубокий контекст: информация о маркетинговых кампаниях, каналах привлечения, изменениях в продукте и геймплейных механиках.

# %% [markdown]
# ### Вывод
#
# Анализ ретеншн и вовлеченности пользователей показал несколько ключевых закономерностей:
#
# * В период с 8 по 12 октября наблюдается резкий рост числа новых пользователей, что, вероятно, связано с маркетинговыми активностями. Однако у когорт 8 и 10 октября значительно ниже показатели удержания (RR1, RR7), что может свидетельствовать о привлечении менее целевой аудитории.
#
# * Когорты 11 и 12 октября, несмотря на массовость, демонстрируют высокие показатели удержания, что говорит о более качественном трафике или удачном онбординге.
#
# * Средняя продолжительность игровых сессий сильно варьируется. Есть аномально длинные сессии (до 1365 минут), что может указывать на технические особенности или ботов.
# * Крайне короткие сессии (≈0 минут) могут быть связаны с техническими проблемами, нерелевантной рекламой или неправильной настройкой онбординга.
#
# * Конверсия в первую сессию ≈ 100% (что редкость в реальных данных).
# * Конверсия во вторую сессию и дальше была ниже у когорт 8–10 октября, что подтверждает гипотезу о проблемах с качеством аудитории или онбордингом.
# * Конверсия в платеж нестабильна, но есть резкие пики 13 и 14 октября, что может быть связано с внутриигровыми событиями или удачными монетизационными механиками.
#
# **Рекомендации**
# * Особое внимание уделить когортам 8–10 октября.
# * Провести анализ каналов трафика, чтобы выявить источники с высоким и низким качеством пользователей.
# * Улучшить онбординг для новых игроков, особенно в период массового притока аудитории.
# * Проверить причины экстремально коротких и длинных сессий (возможные технические проблемы, боты, специфика игрового процесса).
# * Детальнее изучить механики вовлечения и монетизации в период 13–14 октября, когда конверсия в платеж резко увеличилась.
#
# В целом, несмотря на положительные показатели у ряда когорт, выявленные аномалии требуют дополнительного анализа, чтобы повысить удержание и вовлеченность пользователей в долгосрочной перспективе.

# %% [markdown]
# ### 💠 Монетизация

# %% [markdown]
# Общие показатели монетизации
#
# * ARPU (Average Revenue Per User) – средний доход на пользователя
# * ARPPU (Average Revenue Per Paying User) – средний доход на платежеспособного пользователя
# * Paying Share – доля платящих игроков
# * Конверсия в первый платеж – процент игроков, совершивших хотя бы один платеж (Рассчитан на предыдущем этапе.)

# %%
# 1. Определяем сумму выручки по каждому пользователю с учетом его когортной даты.
# 2. Определяем количество платящих пользователей в каждой когорте.
# 3. Определяем общее количество пользователей в каждой когорте.
# 4. Рассчитываем ключевые метрики монетизации по когортам:ARPU, ARPPU, Paying Share.


sql = '''
WITH 
revenue AS (
    SELECT 
        p.user_id, 
        DATE(i.reg_time) AS cohort_date,
        SUM(p.amount) AS total_revenue
    FROM payment p
    JOIN install i ON p.user_id = i.user_id
    GROUP BY 1, 2
),
paying_users AS (
    SELECT 
        DATE(i.reg_time) AS cohort_date,
        COUNT(DISTINCT p.user_id) AS payers
    FROM payment p
    JOIN install i ON p.user_id = i.user_id
    GROUP BY 1
),
total_users AS (
    SELECT 
        DATE(reg_time) AS cohort_date,
        COUNT(user_id) AS total_players
    FROM install 
    GROUP BY 1
)
SELECT 
    t.cohort_date, 
    t.total_players,
    ROUND(COALESCE(SUM(r.total_revenue), 0), 2) AS revenue, 
    p.payers,
    ROUND(COALESCE(SUM(r.total_revenue) / t.total_players, 0), 3) AS arpu,
    ROUND(COALESCE(SUM(r.total_revenue) / NULLIF(p.payers, 0), 0), 3) AS arppu,
    ROUND(COALESCE(p.payers * 1.0 / t.total_players, 0), 3) AS paying_share
FROM total_users t
LEFT JOIN paying_users p ON t.cohort_date = p.cohort_date
LEFT JOIN revenue r ON t.cohort_date = r.cohort_date
GROUP BY t.cohort_date, t.total_players, p.payers
HAVING total_players > 10
ORDER BY t.cohort_date;

'''
df = select(sql)
df["cohort_date"] = pd.to_datetime(df["cohort_date"])
df
# Out:
#   cohort_date  total_players  revenue  payers   arpu  arppu  paying_share
# 0  2020-10-05            380     3.20       2  0.008  1.601         0.005
# 1  2020-10-06            423     3.05       6  0.007  0.508         0.014
# 2  2020-10-07            591     9.98       8  0.017  1.248         0.014
# 3  2020-10-08           1210     0.61       2  0.001  0.305         0.002
# 4  2020-10-09           4855    56.99      18  0.012  3.166         0.004
# 5  2020-10-10           8130     7.84      19  0.001  0.413         0.002
# 6  2020-10-11           7129    16.96      49  0.002  0.346         0.007
# 7  2020-10-12           4991    35.81      47  0.007  0.762         0.009
# 8  2020-10-13           1634   162.15      92  0.099  1.762         0.056
# 9  2020-10-14           1772    85.15      70  0.048  1.216         0.040

# %%
# Визуализируем результаты
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Revenue
sns.barplot(ax=axes[0, 0], x="cohort_date", y="revenue", hue="cohort_date", data=df, palette="Purples")
axes[0, 0].set_title("Revenue по когортам")
axes[0, 0].set_xlabel("Когорта")
axes[0, 0].set_ylabel("Выручка")
axes[0, 0].tick_params(axis='x', rotation=45)

# ARPU
sns.barplot(ax=axes[0, 1], x="cohort_date", y="arpu", hue="cohort_date", data=df, palette="Blues")
axes[0, 1].set_title("ARPU по когортам")
axes[0, 1].set_xlabel("Когорта")
axes[0, 1].set_ylabel("ARPU")
axes[0, 1].tick_params(axis='x', rotation=45)

# ARPPU
sns.barplot(ax=axes[1, 0], x="cohort_date", y="arppu", hue="cohort_date", data=df, palette="Greens")
axes[1, 0].set_title("ARPPU по когортам")
axes[1, 0].set_xlabel("Когорта")
axes[1, 0].set_ylabel("ARPPU")
axes[1, 0].tick_params(axis='x', rotation=45)

# Paying Share
sns.barplot(ax=axes[1, 1], x="cohort_date", y="paying_share", hue="cohort_date", data=df, palette="Reds")
axes[1, 1].set_title("Paying Share по когортам")
axes[1, 1].set_xlabel("Когорта")
axes[1, 1].set_ylabel("Paying Share")
axes[1, 1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Монетизация нестабильна, с низким ARPU и слабой Paying Share на крупных когортных группах (8–12 октября). Особенно заметны резкие всплески ARPU 13–14 октября, что, вероятно, связано с акциями, внутриигровыми событиями или другими стимулирующими факторами.
#
# Когорты 8–12 октября показывают большой приток игроков (от 1,2 тыс. до 8,1 тыс.), но при этом приносят крайне низкий доход.
# Например, у когорты 10 октября при 8 130 игроках ARPU = 0.001, что крайне мало.
# Paying Share (доля платящих игроков) также остаётся очень низкой (0.002–0.009), что указывает на слабую конверсию в платежи.
#
# Возможные причины:
# - Привлечение нерелевантного трафика.
# - Слабые монетизационные триггеры в первые дни.
# - Возможно, игроки не доходят до ключевых платёжных моментов.
#
# Если была активная рекламная кампания в эти дни, стоит проверить её качество.
#
# Резкие скачки ARPU 13 и 14 октября:
# - 13 октября: ARPU = 0.099, Revenue = 162.15, Paying Share = 0.056
# - 14 октября: ARPU = 0.048, Revenue = 85.15, Paying Share = 0.040
#
# Возможные причины:
# - Акции, скидки или внутриигровые события.
# - Повышенная вовлечённость игроков в эти дни.
# - Локальные эффекты от отдельных групп пользователей (например, пришли «киты»).
#
# ARPPU нестабилен, но показывает важные тенденции:
# В среднем ARPPU колеблется от 0.3 до 1.7, с пиком 9 октября — 3.166 (вероятно, одна или несколько крупных транзакций).
#
# Это указывает, что основной доход сосредоточен у небольшого количества пользователей.
# Возможно, платежи делают несколько «китов», а средний игрок платит мало.
#
# ✴️ Выводы и рекомендации:
#
# - Проверить рекламные кампании 8–12 октября. Оценить источники трафика: конверсия в платежи крайне низкая. Возможно, привлекались «холодные» игроки, которые не готовы платить.
# - Разобраться с причинами пиковых ARPU 13–14 октября.
# - Оценить структуру платежей. Кто платит и каков размер платежей.
# - Углублённый анализ по сегментам: по странам, платформам, версиям игры.
# - Также стоит изучить игровую воронку: насколько успешно пользователи проходят ключевые этапы перед первым платежом.

# %% [markdown]
# #### *Метрики необходимые на мой взгляд для анализа воронки монетизации* :
#
# * Конверсии по этапам монетизации: Установки → Доля игроков с первой сессией → Доля игроков, совершивших первый платеж → Доля игроков, совершивших второй платеж
# * Time to First Purchase (days) – среднее время до первого платежа
# * Средний уровень, на котором игрок совершил первый платёж
# * Средний чек первого платежа
# * Purchase Frequency – среднее количество покупок на платящего игрока.

# %%
# 1. Определяем дату первого платежа и сумму первого платежа для каждого игрока
# 2. Определяем дату второго платежа (если он был) после первого платежа
# 3. Определяем средний уровень, на котором игрок совершил первый платеж
# 4. Определяем количество платежей для каждого игрока
# 5. Финальный расчет метрик по когортам:
    # first_payment_conversion -- Конверсия из установки в первый платеж (%)
    # second_payment_conversion -- Конверсия из установки во второй платеж (%)
    # avg_time_to_first_purchase -- Cреднее количество дней, прошедших с момента регистрации до первого платежа.
    # avg_level_first_purchase -- Средний уровень, на котором был совершен первый платеж.
    # avg_first_purchase_amount - Средняя сумма первого платежа.
    # avg_purchase_frequency - Cреднее количество платежей, совершенных каждым пользователем.

sql = '''
WITH
first_purchases AS (
    SELECT user_id, 
           DATE(time) AS first_purchase_date, 
           amount AS first_purchase_amount
      FROM (SELECT *, 
                 ROW_NUMBER() OVER (PARTITION BY user_id ORDER BY time) AS rn 
            FROM payment)
     WHERE rn = 1
),

second_purchases AS (
    SELECT 
        p.user_id, 
        MIN(DATE(p.time)) AS second_purchase_date
    FROM payment p
    JOIN first_purchases fp ON p.user_id = fp.user_id
    WHERE DATE(p.time) > fp.first_purchase_date
    GROUP BY p.user_id
),

avg_level_first_purchase AS (
    SELECT p.user_id, MIN(l.level) AS first_purchase_level
    FROM payment p
    JOIN level_up l ON p.user_id = l.user_id AND DATE(p.time) = DATE(l.time)
    GROUP BY p.user_id
),

purchase_stats AS (
    SELECT 
        user_id,
        COUNT(time) AS purchase_count
    FROM payment
    GROUP BY user_id
)

SELECT 
    DATE(i.reg_time) AS cohort_date,
    COUNT(i.user_id) AS installs,
    COUNT(DISTINCT fp.user_id) AS first_payers,
    COUNT(DISTINCT sp.user_id) AS second_payers,
    ROUND(100.0 * COUNT(DISTINCT fp.user_id) / NULLIF(COUNT(DISTINCT i.user_id), 0), 2) AS first_payment_conversion, 
    ROUND(100.0 * COUNT(DISTINCT sp.user_id) / NULLIF(COUNT(DISTINCT i.user_id), 0), 2) AS second_payment_conversion, 
    ROUND(AVG(fp.first_purchase_date - i.reg_time::date), 2) AS avg_time_to_first_purchase,
    ROUND(AVG(al.first_purchase_level), 2) AS avg_level_first_purchase,
    ROUND(AVG(fp.first_purchase_amount), 2) AS avg_first_purchase_amount,
    ROUND(AVG(ps.purchase_count), 2) AS avg_purchase_frequency
FROM install i 
LEFT JOIN first_purchases fp ON i.user_id = fp.user_id
LEFT JOIN second_purchases sp ON i.user_id = sp.user_id
LEFT JOIN avg_level_first_purchase al ON i.user_id = al.user_id
LEFT JOIN purchase_stats ps ON i.user_id = ps.user_id
GROUP BY 1
ORDER BY 1;

'''

df = select(sql)
df
# Out:
#   cohort_date  installs  first_payers  second_payers  \
# 0  2020-10-05       380             2              1
# 1  2020-10-06       423             6              2
# 2  2020-10-07       591             8              3
# 3  2020-10-08      1210             2              0
# 4  2020-10-09      4855            18              4
# 5  2020-10-10      8130            19              6
# 6  2020-10-11      7129            49              7
# 7  2020-10-12      4991            47             10
# 8  2020-10-13      1634            92             32
# 9  2020-10-14      1772            70             22
#
#    first_payment_conversion  second_payment_conversion  \
# 0                      0.53                       0.26
# 1                      1.42                       0.47
# 2                      1.35                       0.51
# 3                      0.17                       0.00
# 4                      0.37                       0.08
# ...

# %% [markdown]
# ### Вывод
#
# Конверсия в первый платеж варьируется от 0.17% до 5.63%, что указывает на низкую стабильность. Однако, в некоторых когортах наблюдаются значительные пики (например, 13 октября — 5.63% и 14 октября — 3.95%), что может свидетельствовать о временных акциях, промо или изменениях в игровом контенте.
#
# Конверсия во второй платеж значительно ниже (максимум 1.96%), что свидетельствует о слабой удерживаемости платящих игроков. Это может быть связано с недостаточной мотивацией для игроков продолжать совершать покупки или с ограниченным предложением контента.
#
# Средний чек первого платежа остается невысоким во всех когортах, колеблясь в пределах 0.15 - 0.41. Это указывает на то, что игроки не склонны тратить большие суммы на первом этапе игры.
#
# Низкая средняя частота покупок (1-3 покупки) в когортах также говорит о том, что пользователи редко совершают повторные платежи, что еще раз подчеркивает слабое удержание платящих игроков.
#
# Первый платеж совершается на уровнях 5-8, но есть отклонения (например, 3.71 на 7 октября). Это может указывать на несбалансированную монетизацию: некоторые игроки готовы платить рано, а другие не совершают покупок вообще, что может быть связано с трудностями в вовлечении новых пользователей или с неэффективными предложениями на ранних этапах игры.
#
# Среднее время до первого платежа варьируется от 1 до 6 дней в разных когортных группах. В некоторых случаях игроки платят почти сразу (через 1-2 дня), в других — задержка может достигать 4-6 дней. Это может зависеть от игровых механик или предложений, направленных на стимулирование покупок.
#
# ### Рекомендации по улучшению монетизации:
# * Усилить вовлекающие механики на ранних уровнях игры, чтобы стимулировать первый платеж быстрее.
# * Работать над удержанием платящих пользователей, улучшая предложения и персонализируя их, чтобы они совершали повторные покупки.
# * Провести A/B-тестирование по конверсии в платежи, чтобы понять, возможно ли улучшить конверсию в когортах с низкими значениями (исключить барьеры, такие как высокие цены или слабая ценность предложений).
# * Усилить монетизационные триггеры: предложения бонусов за первую покупку, ограниченные по времени акции.
# * Сегментировать платящих пользователей по признакам, таким как страна, демографические данные, платформа и версия игры, а также учитывать влияние источников трафика — это поможет понять, какие каналы привлекают более платежеспособную аудиторию.
# * Проанализировать распределение платежей по типу контента, чтобы понять, какие предложения наиболее привлекательны.
# * Проанализировать точки оттока, чтобы выявить, на каком этапе игроки теряют интерес и что можно сделать для их удержания.
#
# ⚠️ Необходим более детальный анализ.

# %% [markdown]
# ### 💠 Проблемные точки

# %% [markdown]
# Рассчитаем конверсию выполнения квестов.
# Если у определенных квестов низкая конверсия, это может указывать на слишком сложные или неинтересные задания.
# В качестве результата выведем ТОП-10 квестов с самой низкой completion_rate.

# %%
sql = '''
WITH quest_attempts AS (
    SELECT 
        quest, 
        COUNT(DISTINCT user_id) AS players_started
    FROM quest_start
    GROUP BY quest
),
quest_completions AS (
    SELECT 
        quest, 
        COUNT(DISTINCT user_id) AS players_completed
    FROM quest_complete
    GROUP BY quest
)
SELECT 
    q.quest,
    q.players_started,
    COALESCE(c.players_completed, 0) AS players_completed,
    ROUND(COALESCE(c.players_completed, 0) * 100.0 / NULLIF(q.players_started, 0), 2) AS completion_rate
FROM quest_attempts q
LEFT JOIN quest_completions c ON q.quest = c.quest
ORDER BY completion_rate ASC, q.quest;
'''

df = select(sql).head(10)

# %%
plt.figure(figsize=(6, 5))
sns.barplot(y=df["quest"], x=df["completion_rate"], hue = df["quest"], palette="Spectral")

plt.xlabel("Completion Rate (%)")
plt.ylabel("Quest")
plt.title("ТОП-10 квестов с самой низкой completion_rate")
plt.xlim(0, 100)
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# Определимс среднее время выполнения квестов. Если у некоторых квестов оно аномально высокое, стоит проверить их сложность.

# %%
sql = '''
WITH quest_durations AS (
    SELECT 
        qc.quest, 
        qc.user_id,
        DATE_PART('epoch', qc.time - qs.time) / 60 AS duration_minutes
    FROM quest_complete qc
    JOIN quest_start qs 
        ON qc.user_id = qs.user_id 
        AND qc.quest = qs.quest
)

SELECT 
    quest, 
    COUNT(user_id) AS completed_count,
    ROUND(AVG(duration_minutes)::numeric, 2) AS avg_completion_time_minutes
FROM quest_durations
GROUP BY quest
ORDER BY avg_completion_time_minutes DESC;

'''

df = select(sql).head(10)
df
# Out:
#       quest  completed_count  avg_completion_time_minutes
# 0  quest_26             5320                      1498.20
# 1  quest_30             2681                      1471.92
# 2  quest_36             1461                      1157.49
# 3  quest_29             3698                       893.53
# 4  quest_39              770                       814.79
# 5  quest_28             4103                       810.95
# 6  quest_41              584                       718.09
# 7  quest_35             1884                       697.86
# 8  quest_37              975                       696.62
# 9  quest_23             6956                       588.96

# %%
plt.figure(figsize=(6, 5))
sns.barplot(y=df["quest"], x=df["avg_completion_time_minutes"], hue = df["quest"], palette="Spectral")

plt.xlabel("Duration, minutes")
plt.ylabel("Quest")
plt.title("ТОП-10 квестов с самым высоким временем выполнения")
plt.grid(axis="x", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# Рассчитаем конверсию перехода на следующий уровень

# %%
sql = '''

WITH level_counts AS (
    SELECT 
        user_id, 
        level, 
        COUNT(*) AS level_up_count
    FROM level_up
    GROUP BY user_id, level
),

level_conversion AS (
    SELECT 
        lc1.level AS current_level,
        COUNT(DISTINCT lc1.user_id) AS players_at_level,
        COUNT(DISTINCT lc2.user_id) AS players_at_next_level,
        ROUND((COUNT(DISTINCT lc2.user_id) * 100.0) / COUNT(DISTINCT lc1.user_id), 2) AS conversion_rate
    FROM level_counts lc1
    LEFT JOIN level_counts lc2 
        ON lc1.user_id = lc2.user_id 
        AND lc1.level = lc2.level - 1  
    GROUP BY lc1.level
    ORDER BY lc1.level
)

SELECT * FROM level_conversion;
'''

df = select(sql)
df
# Out:
#     current_level  players_at_level  players_at_next_level  conversion_rate
# 0             2.0             25535                  21363            83.66
# 1             3.0             21367                  17863            83.60
# 2             4.0             17863                  14438            80.83
# 3             5.0             14439                  12728            88.15
# 4             6.0             12730                  12084            94.93
# 5             7.0             12084                  10326            85.45
# 6             8.0             10328                   6598            63.88
# 7             9.0              6598                   4033            61.12
# 8            10.0              4034                   2635            65.32
# 9            11.0              2636                   1553            58.92
# 10           12.0              1553                    795            51.19
# ...

# %% [markdown]
# Итак, данные показывают:
#
# 🔹 Падение конверсии на 8–10 уровнях
# С 7 на 8 уровень конверсия падает с 83.66% до 63.88%, что является значительным снижением. Это может свидетельствовать о повышении сложности или мотивации игроков. Падение продолжает наблюдаться и на уровнях 9 и 10, где конверсии остаются ниже 65%. Возможно, игрокам становится сложнее продолжать игру, что может указывать на необходимость улучшения механик или системы вознаграждений.
#
#
# 🔹 Критическое снижение удержания после 11 уровня
# После 11 уровня конверсия начинает стабильно снижаться ниже 60%, достигая минимальных значений на 15 уровне (42.77%). Это может указывать на чрезмерную сложность, недостаточное вознаграждение или нехватку контента на этих уровнях. После 15 уровня наблюдается резкое сокращение количества игроков, что подтверждает рост уровня оттока.
#
# 🔹 Минимальное число игроков на высоких уровнях
# После 15 уровня число игроков резко сокращается. На 20 уровне остается всего 2 человека, а на 21 уровне — никого. Это говорит о том, что большая часть аудитории покидает игру задолго до максимального уровня.
#
#
# ✴️ Рекомендации
# * Проверить, какие механики или квесты вызывают затруднения.
# * Оптимизировать баланс сложности.
# * Добавить более привлекательные награды. Улучшить систему вознаграждений и прогрессии.
# * Провести А/Б-тестирование. Облегчить некоторые задания и отследить изменение конверсии.
#
#
# ### Вывод
# Таким образом, основной проблемой являются 7–15 уровни, где конверсия значительно падает, а количество игроков уменьшается. Для повышения удержания следует оптимизировать сложность игры, улучшить систему вознаграждений и протестировать изменения через А/Б-тесты.
#
# Также, стоит проанализировать, какие задания выпадают на этих уровнях, не становятся ли они слишком сложными или однообразными, требуют ли длительного ожидания или значительных вложений ресурсов.
#
# <br>
#
# 💡 Можно предположить, что игроки испытывают нехватку ресурсов (энергии) на поздних уровнях. Я сам столкнулся с этим в Atlantis Odyssey...
# На 10 уровне у меня закончился стартовый бонус энергии 😅 Играть стало значительно сложнее.
# Вероятно, и другие игроки сталкиваются с нехваткой ресурсов, увеличением времени ожидания или необходимостью доната, что приводит к оттоку. Это может указывать на необходимость пересмотреть баланс расходуемых ресурсов или предложить дополнительные способы их получения.

# %% [markdown]
# ### ***Задание № 3***
# 💠 Какие еще метрики и внутриигровые фичи вы бы отслеживали / анализировали в первую очередь? (Сильно углубляться не надо, достаточно 3-4 примеров)
#
# 1. Tutorial (Анализ туториала и вовлечения новичков)
# Туториал – один из ключевых элементов удержания игроков. Если игроки его не проходят или сразу пропускают, это сигнал о проблемах в первом пользовательском опыте.
#    * Tutorial Retention – доля игроков, завершивших туториал.
#    * Tutorial COR (Completion & Onboarding Rate) – процент завершения туториала (референс 70−80%).
#    * Tutorial Skip Rate – доля игроков, пропустивших туториал.
#
# 2. CARPU N-day (Cumulative ARPU) – Накопительный ARPU за N дней. Метрика, отражающая доход с одного игрока за определенный период. Позволяет анализировать скорость монетизации и оценивать эффективность внутриигровых механик.
#
# 3. Purchase Structure – Структура внутриигровых покупок. Анализ типов покупок , их частоты и распределения. Помогает понять, какие товары наиболее популярны. Позволяет сегментировать платежеспособных игроков.
# Дает информацию для оптимизации цен и промо-акций.
#
# 4. Виртуальная валюта и другие ресурсы. Анализ экономики игры, распределения ресурсов.
# Если игроки копят ресурсы, но не тратят – возможно, нет мотивации на использование.
# Если ресурсы слишком быстро тратятся – возможен дефицит, который может негативно сказаться на удержании.
# Анализируем:  распределение ресурсов по уровням / Траты / Заработок / Покупка / Накопление
#
# 5. Offer Show – Оценка эффективности спецпредложений.
# Метрика, анализирующая, как игроки взаимодействуют с внутриигровыми акциями и предложениями.
#    * Offer Show Rate – сколько раз игроки видят окно спецпредложения.
#    * Offer CTR (Click-Through Rate) – сколько игроков кликнули на предложение после показа.
#    * Offer Conversion Rate – сколько игроков совершили покупку после просмотра оффера.
# Если показатели низкие, стоит изменить наполнение офферов или тестировать A/B-версии.
#
# 6. Виральность
#
#
# 💠 Дополните таблицу выше событиями, которые вам в этом помогут (достаточно около 10 основных событий).
#
# 1. Туториал.
#  Цель: Анализируем, как игроки проходят обучение и вовлекаются в игру.
#
# 🔸 tutorial_start – начало туториала.
#    - user_id (string) – ID игрока
#    - time (timestamp) – Время начала туториала
#
# 🔸tutorial_complete – завершение туториала.
#    - user_id (string) – ID игрока
#    - time (timestamp) – Время завершения туториала
#    - completion_time (numeric) – Время, затраченное на туториал
#    - skipped (boolean) – Пропущен ли туториал
#
# 2. Экономика игры (Ресурсы и покупки)
# Цель: Отслеживаем баланс экономики, накопление и расход ресурсов, покупательское поведение.
#
# 🔸resource_transaction – получение или расход ресурсов.
# - user_id (string) – ID игрока
# - time (timestamp) – Время операции
# - resource_type (string) – Тип ресурса (золото, энергия, билеты и т. д.)
# - amount (numeric) – Количество ресурса
# - transaction_type (string) – earn/spend (получение или расход)
# - source (string) – Источник (битва, сундук, покупка и т. д.)
#
# 🔸 shop_interaction – посещение магазина.
# - user_id (string) – ID игрока
# - time (timestamp) – Время посещения
# - action (string) – view/purchase (просмотр или покупка)
# - item_id (string) – ID товара
# - price (numeric) – Цена (в валюте игры или реальных деньгах)
#
# 3. Монетизация (Спецпредложения и реклама)
# Цель: Оцениваем, насколько эффективны монетизационные механики.
#
# 🔸offer_interaction – взаимодействие со спецпредложением.
# - user_id (string) – ID игрока
# - time (timestamp) – Время взаимодействия
# - offer_id (string) – ID спецпредложения
# - action (string) – view/click/purchase
# - price (numeric) – Цена (если покупка)
#
# 🔸ad_view – просмотр рекламы.
# - user_id (string) – ID игрока
# - time (timestamp) – Время просмотра
# - ad_type (string) – Тип рекламы (баннер, видео, rewarded video и т. д.)
#
# 4. Взаимодействие с игровыми событиями
# Цель: Оцениваем активность игроков в специальных событиях и их влияние на удержание.
#
# 🔸event_participation – участие в игровом событии.
# - user_id (string) – ID игрока
# - time (timestamp) – Время участия
# - event_id (string) – ID ивента
# - progress (numeric) – Насколько игрок прошел событие (%)
# - completion_status (boolean) – Закончил ли игрок событие
#
# 5. Социальные механики
# Цель: Анализируем влияние соц. функций на вовлечение и органический рост.
#
# 🔸 friend_invite – приглашение друга.
# - user_id (string) – ID игрока
# - time (timestamp) – Время отправки приглашения
# - friend_id (string) – ID приглашенного игрока
# - accepted (boolean) – Принял ли друг приглашение
#
# ⚠️ Я указал 8 событий, конечно же, не потому, что больше ничего не придумал 😅, а потому, что хранение данных стоит денег. При ограниченном бюджете важно сосредоточиться на ключевых событиях с развернутыми атрибутами, чтобы сократить объём записей и сохранить ценность для анализа.
# Кроме того, слишком детализированный лог усложняет работу аналитиков: чем больше «шума» в данных, тем сложнее находить полезные инсайты.

# %% [markdown]
# ### ***Задание № 4***
#
# 💠 4. Опишите стратегию дальнейшего анализа на основании предложенных вами
# событий.

# %% [markdown]
# Стратегия дальнейшего анализа на основании предложенных событий:
#
# 1. Анализ онбординга и вовлечения новичков.
# Одним из ключевых этапов игрового опыта является процесс онбординга новых игроков. Для его оценки необходимо:
#
# - Рассчитать Tutorial Retention (долю игроков, завершивших туториал), Completion & Onboarding Rate (COR) (процент завершения туториала) и Skip Rate (долю игроков, пропустивших обучение).
# - Выявить узкие места, на которых пользователи чаще всего покидают игру.
# - Провести сегментацию игроков по способу прохождения: полностью завершившие туториал, частично завершившие и пропустившие обучение.
# - Дополнительно можно провести A/B-тестирование альтернативных версий туториала, изменяя его продолжительность, подачу информации и интерактивные элементы.
#
# <br>
#
# 2. Оценка монетизации и внутриигровых покупок.
# Для понимания платежного поведения игроков необходимо:
#
# - Анализировать Cumulative ARPU (CARPU) – накопительный доход с одного игрока за определенные периоды. Это позволит определить, как быстро пользователи начинают платить и какие факторы на это влияют.
# - Изучить структуру внутриигровых покупок (Purchase Structure), выделяя наиболее популярные категории товаров и ценовые сегменты.
# - Оценить конверсию в первую покупку, выявляя, какой процент игроков совершает платеж и на каком этапе игры.
# - Дополнительно можно проводить A/B-тестирование ценовых моделей, скидок и специальных предложений для увеличения дохода.
#
# <br>
#
# 3. Исследование внутриигровой экономики.
# Баланс игровой экономики – важный фактор удержания игроков. Для его анализа необходимо:
# - Сравнить поступление ресурсов (resource_earn) и их расход (resource_spend). Если игроки копят валюту, но не тратят, возможно, нет стимулов для покупок. Если ресурсы быстро заканчиваются, это может негативно сказаться на удержании.
# - Проанализировать поведение игроков с разными моделями расходования: кто-то может активно тратить ресурсы, а кто-то их накапливать.
# - Оценить влияние ограничений на экономику: является ли дефицит ресурсов проблемой или он стимулирует дополнительные покупки.
# - Если выявляются дисбалансы, стоит адаптировать внутриигровую экономику, изменяя генерацию и расход ресурсов.
#
# <br>
#
# 4. Оптимизация спецпредложений и рекламы.
# Чтобы повысить эффективность внутриигровых акций и рекламных механик, необходимо:
# - Рассчитать Offer CTR (Click-Through Rate) и Offer Conversion Rate, чтобы понять, какие спецпредложения привлекают игроков и конвертируются в покупки.
# - Оценить Ad Engagement Rate, анализируя вовлеченность пользователей в рекламу и ее влияние на монетизацию.
# - Сегментировать игроков по реакции на спецпредложения: кто активно использует их, кто игнорирует, а кто проявляет интерес, но не совершает покупку.
# - Дополнительно можно проводить A/B-тестирование различных форматов предложений, изменяя их содержимое, цену и время показа.
#
# <br>
#
# 5. Влияние игровых ивентов и социальных механик.
#  Ивенты и социальные механики способны значительно повысить вовлеченность игроков. Для их оценки важно:
# - Анализировать участие в ивентах (event_participation) и их успешное завершение (event_complete). Это позволит понять, насколько игроки заинтересованы в таких активностях и какие факторы влияют на их завершение.
# - Оценить эффективность системы приглашений (friend_invite), выявляя, насколько активно пользователи привлекают друзей.
# - Проанализировать влияние ивентов на ключевые метрики, такие как удержание и ARPU, чтобы понять, увеличивается ли доход и активность во время событий.
# - Если какие-то игровые события показывают низкую вовлеченность, стоит адаптировать их механику, предлагая более ценные награды или изменяя условия участия.
#
# <br>
#
# ### Вывод
#
# Предложенная стратегия позволит выявить проблемные точки в игровом процессе, экономике и монетизации. На основе полученных данных можно адаптировать ключевые механики: улучшить онбординг, сбалансировать игровую экономику, оптимизировать систему предложений и ивентов. Это приведет к повышению удержания, вовлеченности и монетизации пользователей.

# %% [markdown]
# -----

# %% [markdown]
# ###  Спасибо за интересное тестовое, было полезно поразмышлять над задачами! Хорошего дня! 😊🤝
